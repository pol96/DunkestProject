# %%
#!pip install webdriver-manager

# %%
import requests as re
from webdriver_manager.chrome import ChromeDriverManager

import selenium
from selenium import webdriver
from selenium.webdriver.support.ui import Select, WebDriverWait

from bs4 import BeautifulSoup as bs

import pandas as pd
from time import sleep
import getpass
import base64 

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
def dunkest_scraping(email, password, id_players = range(1,5), filter_season = 'Regular Season 20/21'):
    '''
    Recall from Dunkest website all specific statistics game-by-game per player (selected all)
    Variables:
        - email (login email)
        - password (login password)
        - start_id_player (to filter out some players. it will run till exhaustion of ids)
        - filter_season (selected )
    '''
    password = base64.b64encode(getpass.getpass('Password:').encode("utf-8"))
    df = pd.DataFrame()  
    URL = 'https://nba.dunkest.com/it/home'
    # create the initial window
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.maximize_window()  
    # go to the home page
    driver.get(URL)


    sleep(4)

    driver.find_element_by_xpath('//*[@class = "iubenda-cs-opt-group-consent"]').click()
    sleep(1)
    driver.find_element_by_xpath('//*[@class ="dun-btn dun-btn--brand-03 dun-btn--login"]').click()
    sleep(1)

    email = 'pticozzi1996@gmail.com'
    password = 'finoaquittbn'  
    # enter the email
    driver.find_element_by_xpath('//*[@name ="email"]').send_keys(email)
    driver.find_element_by_xpath('//*[@class ="dun-btn"]').click()  

    sleep(1)

    # enter the password
    driver.find_element_by_xpath('//*[@name ="password"]').send_keys(base64.b64decode(password).decode("utf-8"))
    driver.find_element_by_xpath('/html/body/app-root/div/app-layout-dashboard/app-header/app-login/app-modal/div[1]/div/div/div/div[2]/div[2]/div[2]/button[2]').click()  
    sleep(4)

    # get into player stat page 
    window_before = driver.window_handles[0]
    for i in id_players:
        myurl = "'https://www.dunkest.com/it/giocatore/" +str(i) + "/nikola-jokic?iframe=yes'"
        myurlAction = 'window.open('+myurl+')'
        driver.execute_script(myurlAction)
        window_after = driver.window_handles[1]
        driver.switch_to_window(window_after)
        sleep(1)

        sleep(1)
        try:
            select = Select(driver.find_element_by_xpath('//*[@id="seasonSelect"]'))
            select.select_by_visible_text('Regular Season 20/21')
            sleep(0.66)
            driver.find_element_by_xpath('/html/body/main/div[2]/div/ul/li[2]/span').click()
            sleep(3)
            tab = driver.find_element_by_xpath('//*[@id="gamesTable"]')
            source = tab.get_attribute('innerHTML')
            soup = bs(source)
            data = []
            table_body = soup.find('tbody')

            rows = table_body.find_all('tr')

            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                data.append([ele for ele in cols if ele]) # Get rid of empty values

            final = pd.DataFrame.from_records(data)
            final['Player'] = driver.find_element_by_xpath('//*[@class = "player-info__firstname"]').text + ' ' +  driver.find_element_by_xpath('//*[@class = "player-info__lastname"]').text
            final.columns = ['Data','vs','PDK','MIN','ST','PTS','REB','AST','STL','BLK','BA','FGM','FGA','FG%','3PM','3PA','3P%','FTM','FTA','FT%','OREB','DREB','TOV','PF','+/-','Player']
            df = df.append(final, ignore_index = True)
            driver.close()
            driver.switch_to_window(window_before)
        except:
            driver.close()
            driver.switch_to_window(window_before)
            pass
    driver.quit()
    return(df)

def credits_scraping(email, season_id = '5',mode = 'NBA', stats_type = 'avg', start_from = '2020-12-22', end_to = '2021-05-16', verbose = True):
    password = base64.b64encode(getpass.getpass('Password:').encode("utf-8"))
    df = pd.DataFrame()  
    URL = 'https://nba.dunkest.com/it/home'
    # create the initial window
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.maximize_window()  
    # go to the home page
    driver.get(URL)


    sleep(4)

    driver.find_element_by_xpath('//*[@class = "iubenda-cs-opt-group-consent"]').click()
    sleep(1)
    driver.find_element_by_xpath('//*[@class ="dun-btn dun-btn--brand-03 dun-btn--login"]').click()
    sleep(1)

    # enter the email
    driver.find_element_by_xpath('//*[@name ="email"]').send_keys(email)
    driver.find_element_by_xpath('//*[@class ="dun-btn"]').click()  

    sleep(1)

    # enter the password
    driver.find_element_by_xpath('//*[@name ="password"]').send_keys(base64.b64decode(password).decode("utf-8"))
    driver.find_element_by_xpath('/html/body/app-root/div/app-layout-dashboard/app-header/app-login/app-modal/div[1]/div/div/div/div[2]/div[2]/div[2]/button[2]').click()  
    sleep(4)

    # get into player stat page 
    window_before = driver.window_handles[0]

    myurl = "'https://www.dunkest.com/it/nba/statistiche/giocatori/tabellone?season_id="+season_id+"&mode="+mode+"&stats_type="+stats_type+"&date_from="+start_from+"&date_to="+end_to+"&teams[]=1&teams[]=2&teams[]=3&teams[]=4&teams[]=5&teams[]=6&teams[]=7&teams[]=8&teams[]=9&teams[]=10&teams[]=11&teams[]=12&teams[]=13&teams[]=14&teams[]=15&teams[]=16&teams[]=17&teams[]=18&teams[]=19&teams[]=20&teams[]=21&teams[]=22&teams[]=23&teams[]=24&teams[]=25&teams[]=26&teams[]=27&teams[]=28&teams[]=29&teams[]=30&positions[]=1&positions[]=2&positions[]=3&player_search=&min_cr=4&max_cr=30&sort_by=pdk&sort_order=desc&iframe=yes'"
    if verbose == True:
        print(myurl)
    myurlAction = 'window.open('+myurl+')'

    driver.execute_script(myurlAction)
    window_after = driver.window_handles[1]
    driver.switch_to_window(window_after)
    sleep(0.66)

    df = pd.DataFrame()
    last_page = int(driver.find_element_by_xpath('//*[@class = "paginationjs-page paginationjs-last J-paginationjs-page"]').text)
    counter = 0
    while counter < last_page:
        try:
            tab = driver.find_element_by_xpath('/html/body/main/div[2]/table')
            source = tab.get_attribute('innerHTML')
            soup = bs(source)
            data = []
            table_body = soup.find('tbody')

            rows = table_body.find_all('tr')

            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                data.append([ele for ele in cols if ele]) # Get rid of empty values

            final = pd.DataFrame.from_records(data)
            df = df.append(final, ignore_index = True)
            driver.find_element_by_xpath('//*[@class = "paginationjs-next J-paginationjs-next"]').click()
            counter +=1
        except:
            break
    driver.quit()
    df.columns = ['Player','Role','Team','PDK','CR','GP','MIN','ST','PTS','REB','AST','STL','BLK','BA','FGM','FGA','FGperc','P3M','P3A','P3perc','FTM','FTA','FTperc','OREB','DREB','TOV','PF','PlusMinus']
    return(df)

def export_df(mail, pwd, path = r'C:\Users\ptico\Downloads\\', ranges = range(1,1000), credits = True):
    '''
    exporting df in csv format.
    Variables
        - mail (login email)
        - pwd (login password)
        - path (download pointer)
        - name (filename)
        - ranges (id range for selecting downloadable stats for players)
    '''
    if credits:
        name = 'DUN_credits'
        data = credits_scraping(mail, pwd)
    else:
        name = 'DUN_players'
        data = dunkest_scraping(email = mail, id_players = ranges)
    data.to_csv(path+name+'.csv', sep = ',', index = False)
    print(f'download finished for {name}')

# %%
# export_df(mail = 'pticozzi1996@gmail.com',
#           path = 'C:\ProgramData\MySQL\MySQL Server 8.0\Uploads',
#           credits = False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [C:\Users\ptico\.wdm\drivers\chromedriver\win32\93.0.4577.63\chromedriver.exe] found in cache

# %%
credits_scraping(email = 'pticozzi1996@gmail.com')
# Out:
# Password: ············
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# There is no [win32] chromedriver for browser 94.0.4606 in cache
# Get LATEST driver version for 94.0.4606
# Trying to download new driver from https://chromedriver.storage.googleapis.com/94.0.4606.61/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\ptico\.wdm\drivers\chromedriver\win32\94.0.4606.61]
# 'https://www.dunkest.com/it/nba/statistiche/giocatori/tabellone?season_id=5&mode=NBA&stats_type=avg&date_from=2020-12-22&date_to=2021-05-16&teams[]=1&teams[]=2&teams[]=3&teams[]=4&teams[]=5&teams[]=6&teams[]=7&teams[]=8&teams[]=9&teams[]=10&teams[]=11&teams[]=12&teams[]=13&teams[]=14&teams[]=15&teams[]=16&teams[]=17&teams[]=18&teams[]=19&teams[]=20&teams[]=21&teams[]=22&teams[]=23&teams[]=24&teams[]=25&teams[]=26&teams[]=27&teams[]=28&teams[]=29&teams[]=30&positions[]=1&positions[]=2&positions[]=3&player_search=&min_cr=4&max_cr=30&sort_by=pdk&sort_order=desc&iframe=yes'
#                Player Role Team   PDK    CR  GP   MIN  ST   PTS   REB  ...  \
# 0            N. Jokic    C  DEN  47.1  26.2  72  34.5  72  26.4  10.8  ...
# 1           J. Harden    G  BKN  42.4  22.1  44  36.6  43  24.6   7.9  ...
# 2        R. Westbrook    G  WAS  41.8  26.1  65  36.4  65  22.2  11.5  ...
# 3    G. Antetokounmpo    A  MIL  41.2  22.1  61  33.0  61  28.1  11.0  ...
# 4           J. Embiid    C  PHI  37.7  19.2  51  31.1  51  28.5  10.5  ...
# ..                ...  ...  ...   ...   ...  ..   ...  ..   ...   ...  ...
# 493          T. Terry    G  DAL  -0.3   4.0  11   5.1   0   1.0   0.5  ...
# 494         A. Mokoka    G  CHI  -0.8   4.0  14   4.0   0   1.1   0.4  ...
# 495           K. Dunn    G  ATL  -0.9   4.0   4  11.4   0   1.3   1.5  ...
# 496        D. Louzada    G  NOP  -1.8   0.0   3  18.8   0   2.7   1.0  ...
# 497         J. Martin    G  CLE  -2.3   4.0   9   8.4   0   2.4   0.8  ...
#
#      P3A P3perc  FTM   FTA FTperc OREB DREB  TOV   PF PlusMinus
# 0    3.3   38.8  4.8   5.5   86.8  2.8  8.0  3.1  2.7       5.3
# 1    7.6   36.2  6.3   7.3   86.1  0.8  7.1  4.0  2.3       2.3
# 2    4.2   31.5  4.2   6.4   65.6  1.7  9.9  4.8  2.9      -1.3
# 3    3.6   30.3  6.5   9.5   68.5  1.6  9.4  3.4  2.8       6.7
# 4    3.0   37.4  9.2  10.7   85.9  2.2  8.3  3.1  2.4       7.9
# ..   ...    ...  ...   ...    ...  ...  ...  ...  ...       ...
# 493  0.6    0.0  0.1   0.3   33.3  0.0  0.5  0.2  0.2       0.0
# 494  0.7   10.0  0.0   0.1    0.0  0.1  0.3  0.4  0.4      -0.6
# 495  0.5    0.0  0.8   1.0   75.0  0.0  1.5  0.8  2.5      -7.8
# 496  2.7   25.0  0.0   0.0    0.0  0.3  0.7  1.0  1.7      -3.7
# 497  1.3   25.0  0.1   0.6   20.0  0.2  0.6  0.7  0.1      -2.9
#
# [498 rows x 28 columns]
